# %%
import pandas as pd

# Read the CSV file
df_top_30_genres = pd.read_csv('top_30_genres.csv')
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
df_top_30_genres
# Out:
#                 Id                                              Title  Price  \
# 0       0802841899  The Church of Christ: A Biblical Ecclesiology ...  25.97
# 1       0802841899  The Church of Christ: A Biblical Ecclesiology ...  25.97
# 2       0802841899  The Church of Christ: A Biblical Ecclesiology ...  25.97
# 3       0802841899  The Church of Christ: A Biblical Ecclesiology ...  25.97
# 4       0887402216                            The Battleship Bismarck  34.95
# ...            ...                                                ...    ...
# 157663  1585676187                             Anthony Powell: A Life  29.95
# 157664  1585676187                             Anthony Powell: A Life  29.95
# 157665  1585676187                             Anthony Powell: A Life  29.95
# 157666  1585676187                             Anthony Powell: A Life  29.95
# 157667  1585676187                             Anthony Powell: A Life  29.95
#
#                User_id            profileName review/helpfulness  \
# 0        ARI272XF8TOL4    Christopher J. Bray              74/81
# 1        A36TPZSH8LBT1                haskell                2/3
# 2        ANX3DDV12ZRRU   GodsBreath.wordpress                2/3
# 3       A2H2LORTA5EZY2         Edward E. Howe                3/5
# 4       A30IUAABSEHEPI       Lawrence Duckles                9/9
# ...                ...                    ...                ...
# 157663  A117TCJ30OUVLK                   hola               9/10
# 157664  A30TK6U7DNS82R          Kevin Killian              13/16
# 157665  A2HXQ64JSAXII8   Rampaging Hippogriff               8/10
# 157666  A37P779U3Y116A              Historied                2/2
# 157667  A223P7WP7V0IGR  J. Stockwell "joereb"                1/2
#
#         review/score  review/time  \
# 0                5.0    955411200
# 1                5.0   1311465600
# 2                4.0   1289952000
# 3                4.0   1266192000
# 4                3.0   1055980800
# ...              ...          ...
# 157663           5.0   1199577600
# 157664           4.0   1122163200
# 157665           1.0   1235174400
# 157666           4.0   1281225600
# 157667           5.0   1206316800
#
#                                            review/summary  \
# 0                               Ecclesiological Milestone
# 1               Early Christian development of the Church
# 2       An Excellent Presentation of the Beliefs of th...
# 3                                          Christ is Lord
# 4                        The Battleship Bismarck reviewed
# ...                                                   ...
# 157663                 A dance to the music of the author
# 157664                      Fails to Bring Powell to Life
# 157665               Dance to no music with two left feet
# 157666       Reasonable biography of a fascinating author
# 157667                First-rate copy of first-rate book.
#
#                                               review/text  \
# 0       With the publication of Everett Ferguson's boo...
# 1       Everett Ferguson approaches the subject of ear...
# 2       This book is a continual resource. It is so bi...
# 3       This is a very useful and thorough text book. ...
# 4       This book is both a history and a photo album ...
# ...                                                   ...
# 157663  For any fan of the incredible series "A Dance ...
# 157664  Michael Barber's immense biography is a benchm...
# 157665  Having thoroughly enjoyed both my readings of ...
# 157666  I suppose I am biased in that I really like An...
# 157667  Powell tends to rank higher and higher among 2...
#
#                                               description  \
# 0       In The Church of Christ: A Biblical Ecclesiolo...
# 1       In The Church of Christ: A Biblical Ecclesiolo...
# 2       In The Church of Christ: A Biblical Ecclesiolo...
# 3       In The Church of Christ: A Biblical Ecclesiolo...
# 4       The Bismarck is perhaps the most famous – and ...
# ...                                                   ...
# 157663  "Powell believed that creative writing was, li...
# 157664  "Powell believed that creative writing was, li...
# 157665  "Powell believed that creative writing was, li...
# 157666  "Powell believed that creative writing was, li...
# 157667  "Powell believed that creative writing was, li...
#
#                                      authors                   publisher  \
# 0                       ['Everett Ferguson']  Wm. B. Eerdmans Publishing
# 1                       ['Everett Ferguson']  Wm. B. Eerdmans Publishing
# 2                       ['Everett Ferguson']  Wm. B. Eerdmans Publishing
# 3                       ['Everett Ferguson']  Wm. B. Eerdmans Publishing
# 4                       ['Stefan Draminski']       Bloomsbury Publishing
# ...                                      ...                         ...
# 157663  ['Michael Barber', 'Anthony Powell']              Overlook Press
# 157664  ['Michael Barber', 'Anthony Powell']              Overlook Press
# 157665  ['Michael Barber', 'Anthony Powell']              Overlook Press
# 157666  ['Michael Barber', 'Anthony Powell']              Overlook Press
# 157667  ['Michael Barber', 'Anthony Powell']              Overlook Press
#
#        publishedDate                     categories  ratingsCount
# 0               1996                   ['Religion']           5.0
# 1               1996                   ['Religion']           5.0
# 2               1996                   ['Religion']           5.0
# 3               1996                   ['Religion']           5.0
# 4         2018-09-20                    ['History']           1.0
# ...              ...                            ...           ...
# 157663    2004-09-02  ['Biography & Autobiography']           1.0
# 157664    2004-09-02  ['Biography & Autobiography']           1.0
# 157665    2004-09-02  ['Biography & Autobiography']           1.0
# 157666    2004-09-02  ['Biography & Autobiography']           1.0
# 157667    2004-09-02  ['Biography & Autobiography']           1.0
#
# [157668 rows x 16 columns]

# %%
top_30_genres = df_top_30_genres['categories'].value_counts().head(30).index.tolist()

# %%
# HOW MANY REVIEWS ARE IN THE 30TH GENRE?

thirtieth_genre = top_30_genres[29]

genre_30_df = df_top_30_genres[df_top_30_genres['categories'] == thirtieth_genre]

num_reviews_in_30th_genre = len(genre_30_df)

print(num_reviews_in_30th_genre)
# Out:
# 1142

# %%
# TO RANDOM SAMPLE 1100 REVIEWS FROM THE TOP 30 GENRES 

import pandas as pd

# initialize an empty DataFrame to store the random samples
random_samples_df = pd.DataFrame()

num_reviews_to_sample = 1100

# loop through each genre and sample 1100 reviews
for genre in top_30_genres:
    # Filter the DataFrame for the current genre
    genre_df = df_top_30_genres[df_top_30_genres['categories'] == genre]
    
    if len(genre_df) >= num_reviews_to_sample:
        # Sample reviews randomly
        random_sample = genre_df.sample(n=num_reviews_to_sample, random_state=42) 
        
        # Append the random sample to the results DataFrame
        random_samples_df = pd.concat([random_samples_df, random_sample], ignore_index=True)
    else:
        random_samples_df = pd.concat([random_samples_df, genre_df], ignore_index=True)

random_samples_df = random_samples_df.reset_index(drop=True)

# %%
random_samples_df
# Out:
#                Id                                              Title  Price  \
# 0      1590868218                 Across the Years (Desert Roses #2)  62.25
# 1      0811846040                                   Any Bitter Thing  23.95
# 2      1597370290  The Renegades of Pern (Dragonriders of Pern Se...  24.95
# 3      0748608370                                    Treasure Island  54.00
# 4      042516294X                         North of Havana (Doc Ford)   7.57
# ...           ...                                                ...    ...
# 32995  0767913469  Wedding Blessings: Prayers and Poems Celebrati...  10.88
# 32996  B000FGGOJA                    Principles of Quantum Mechanics  19.00
# 32997  0060891548  On Writing Well, 30th Anniversary Edition: The...  10.87
# 32998  080652636X  Mother Of The Groom: Everything you Need to Kn...  14.96
# 32999  0609604260       The Best of Martha Stewart Living : Weddings  34.65
#
#               User_id                        profileName review/helpfulness  \
# 0      A2XQEOWNC1HVQB                    Elizabeth Merry                4/6
# 1      A1GESGQH3RC5PN          Reader from western Maine                9/9
# 2      A3ADQ3TJ9K3772                      Kristen Bryan                4/5
# 3       AZSNQ9FYC5SQO                              Karri                0/0
# 4      A1FQNMM3OPAK7J  Jason DeJongh (jtdejongh@aol.com)                9/9
# ...               ...                                ...                ...
# 32995  A32J48LYJ2BNNY                       Monty Rainey              14/27
# 32996  A32XTBG7I4HC1E                    Jeremy Harrison               5/28
# 32997  A2LPHYO8TZIDPB                             Reenie                2/2
# 32998  A35K3VE3D8FCAP                Lorraine M. Skarupa                1/1
# 32999  A3EVCX8ZKZA6X7             Shirley A. Asafoboakye                1/4
#
#        review/score  review/time                          review/summary  \
# 0               5.0   1082073600      Another Keeper for Tracie Peterson
# 1               5.0   1117929600                        Not to Be Missed
# 2               2.0    951350400                 Not Her Best Work . . .
# 3               5.0   1360713600                                 classic
# 4               5.0    922406400  This is Randy Wayne White's best book.
# ...             ...          ...                                     ...
# 32995           5.0   1148342400                                 Unique!
# 32996           2.0   1135123200                               Just Okay
# 32997           5.0   1182038400          Excellent resource for writers
# 32998           5.0   1353542400                                    book
# 32999           5.0   1188777600                               excellent
#
#                                              review/text  \
# 0      This book for me started a little slow but the...
# 1      Readers who have followed Monica Wood's fictio...
# 2      I found that the Renegades of Pern was good fo...
# 3      THis was a great book. It was very entertainin...
# 4      A little less than a year ago I was attending ...
# ...                                                  ...
# 32995  Are you looking for a special blessing for a w...
# 32996  I got this book for undergrad because it had a...
# 32997  I will re-read this book at least once a year....
# 32998  Good produce so a high rating.yes, i would tel...
# 32999  Martha Stewart has been my role model and cont...
#
#                                              description  \
# 0      Book 2 of DESERT ROSES. The last ten years hav...
# 1      Richard Russo has celebrated Monica Wood's fic...
# 2      The inhabitants of Pern are threatened by a ba...
# 3      Treasure Island, published in 1883, popularize...
# 4      Randy Wayne White's Doc Ford novels have been ...
# ...                                                  ...
# 32995  A beautiful collection of poems, prayers, and ...
# 32996  "The standard work in the fundamental principl...
# 32997  On Writing Well has been praised for its sound...
# 32998  It’s not just about the rehearsal dinner anymo...
# 32999  Covers all aspects of weddings, from cake to c...
#
#                           authors                       publisher  \
# 0             ['Tracie Peterson']                     Baker Books
# 1                 ['Monica Wood']                 Chronicle Books
# 2              ['Anne McCaffrey']  Dragonriders of Pern (Paperbac
# 3      ['Robert Louis Stevenson']                 Bantam Classics
# 4           ['Randy Wayne White']                         Penguin
# ...                           ...                             ...
# 32995             ['June Cotner']                           Crown
# 32996          ['P. A. M. Dirac']                 Lulu Press, Inc
# 32997         ['William Zinsser']                  Harper Collins
# 32998           ['Sharon Naylor']                   Citadel Press
# 32999          ['Martha Stewart']      Clarkson Potter Publishers
#
#       publishedDate     categories  ratingsCount  sentiment_score  year
# 0        2003-01-01    ['Fiction']          11.0         0.271250  2003
# 1        2010-07-01    ['Fiction']          15.0         0.201282  2010
# 2              1990    ['Fiction']          10.0         0.173843  1990
# 3              1883    ['Fiction']         894.0         0.512500  1883
# 4        1998-05-01    ['Fiction']           4.0         0.115221  1998
# ...             ...            ...           ...              ...   ...
# 32995    2008-11-19  ['Reference']           1.0         0.216344  2008
# 32996    2019-12-01  ['Reference']           2.0         0.202614  2019
# 32997    2006-05-09  ['Reference']          27.0         0.085000  2006
# 32998    2015-03-20  ['Reference']           1.0         0.430000  2015
# 32999          1999  ['Reference']           1.0         0.483333  1999
#
# [33000 rows x 18 columns]

# %%
# VISUALIZE HOW MANY BOOKS BELONG IN EACH GENRE/CATEGORY

import matplotlib.pyplot as plt
import seaborn as sns

genre_counts = random_samples_df['categories'].value_counts()
# bar chart
plt.figure(figsize=(10, 6))  

sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
plt.xticks(rotation=90) 
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Distribution of Book Genres')
plt.tight_layout()

plt.show()

# %%
# CALCUALTE AVERAGE RATINGS BY GENRE AND DISPLAY PLOT FOR AVERAGE RATINGS

genre_ratings = random_samples_df.groupby('categories')['review/score'].mean()
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))  
sns.barplot(x=genre_ratings.index, y=genre_ratings.values, palette='viridis')
plt.xticks(rotation=90)  
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.title('Average Ratings by Genre')
plt.tight_layout()
plt.show()

# %%
# CREATE COLUMN FOR SENTIMENT ANALYSIS SCORE
from textblob import TextBlob
import pandas as pd

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

random_samples_df['sentiment_score'] = random_samples_df['review/text'].apply(get_sentiment)

# %%
# INITIAL SENTIMENT ANALYSIS SCORE ACROSS GENRES
# BOXPLOT OF SENTIMENT ANALYSIS SCORES

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

sns.boxplot(x='categories', y='sentiment_score', data=random_samples_df, palette='Set3')

plt.xticks(rotation=90)  
plt.xlabel('Genre')
plt.ylabel('Sentiment Score')
plt.title('Sentiment Scores of Reviews Across Genres')

plt.show()

# %%
# BARCHART OF SENTIMENT ANALYSIS SCORES

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

sns.barplot(x='categories', y='sentiment_score', data=random_samples_df, palette='Set3')

plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('Average Sentiment Score')
plt.title('Average Sentiment Scores of Reviews Across Genres')

plt.show()
